# %%
#Börja med att göra en övergripande indelning genom def namn. 

def main():
    read_data_from_file()
    save_datapoints_in_datastructure()
    plot_matplotlib()
    calculate_euclidean_distance()
    shortest_distance_testpoints()
    classifie_testpoints()

    print("The 4 testpoints are classified as:")

    #try-catch i den
    user_input_exercise_1()
    #åberopa tidigare uträkning shortest_distance_testpoint.
    classifie_user_testpoint()

    print("Exercise 1) The user input tespoint is classiefied as: ")

    #åberopar samma user input till den med 10 st närmaste. Blir samma kod bara sparad på annat ställe.
    user_input_excercise_2()
    shortest_distance_testpoints_exercise_2()
    ten_closest_distances()
    majority_to_classifie_testpoint()

    print("Exercise 2) The user testpoint is classified as: (based on ten majority votes.)")

#Metoder nedan

def read_data_from_file():
    ...

def save_datapoints_in_datastructure():
    ...

def plot_matplotlib():
    ...

def calculate_euclidean_distance():
    ...

def shortest_distance_testpoints():
    ...

def classifie_testpoints():
    ...

def user_input_exercise_1():
    ...

def classifie_user_testpoint():
    ...

def user_input_excercise_2():
    ...

def shortest_distance_testpoints_exercise_2():
    ...

def ten_closest_distances():
    ...

def majority_to_classifie_testpoint():
    ...

#anropar main
main()
