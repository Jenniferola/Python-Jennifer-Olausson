# %%
import csv
import math
import matplotlib.pyplot as plt 

# Changed the file extension in datapoints from .txt to .csv.


#Variables

pokemons = []
distance_list = []

testpoints_x_values_width = []
testpoints_y_values_height = []

pichu_datapoints = []
pichu_x_values_width = []
pichu_y_values_height =[]

pikachu_datapoints = []
pikachu_x_values_width = []
pikachu_y_values_height =[]


# Testpoints list
testpoint_1_PIKACHU_distances = []
testpoint_1_sorted_PIKACHU_distances = []

testpoint_1_PICHU_distances = []
testpoint_1_sorted_PICHU_distances = []


testpoint_2_PIKACHU_distances = []
testpoint_2_sorted_PIKACHU_distances = []

testpoint_2_PICHU_distances = []
testpoint_2_sorted_PICHU_distances = []


testpoint_3_PIKACHU_distances = []
testpoint_3_sorted_PIKACHU_distances = []

testpoint_3_PICHU_distances = []
testpoint_3_sorted_PICHU_distances = []

testpoint_4_PIKACHU_distances = []
testpoint_4_sorted_PIKACHU_distances = []

testpoint_4_PICHU_distances = []
testpoint_4_sorted_PICHU_distances = []


global user_input_PIKACHU_distances
user_input_PIKACHU_distances = []

global user_input_sorted_PIKACHU_distances
user_input_sorted_PIKACHU_distances = []

global user_input_PICHU_distances
user_input_PICHU_distances = []

global user_input_sorted_PICHU_distances
user_input_sorted_PICHU_distances = []


user_testpoint = []

One_of_ten_PIKACHU_closest_disstance = []
One_of_ten_PICHU_closest_disstance = []

user_input = []



def main():
    reader = read_data_from_file()
    pokemons = save_datapoints_in_datastructure(reader)

    pichu_x_values_width = divide_pikachu_and_pichu(pokemons, pichu_datapoints, 0, pichu_x_values_width, "width")
    pichu_y_values_height = divide_pikachu_and_pichu(pokemons, pichu_datapoints, 0, pichu_y_values_height, "height")
    pikachu_x_values_width = divide_pikachu_and_pichu(pokemons, pikachu_datapoints, 1, pichu_x_values_width, "width")
    pikachu_y_values_height = divide_pikachu_and_pichu(pokemons, pikachu_datapoints, 1, pichu_y_values_height, "height")
    

    plot_matplotlib(pichu_x_values_width, pichu_y_values_height, pikachu_x_values_width,pikachu_y_values_height)


#Här är jag!!!!!!!!!!!!!




    # testpoint 1 

    calculate_euclidean_distance(testpoints_ordered[0],testpoints_ordered[1],pikachu_x_values_width[i],pikachu_y_values_height[i])
    shortest_distance_testpoints(testpoint_1_PIKACHU_distances, testpoint_1_sorted_PIKACHU_distances)

    calculate_euclidean_distance(testpoints_ordered[0], testpoints_ordered[1],pichu_x_values_width[i],pichu_y_values_height[i])
    shortest_distance_testpoints(testpoint_1_PICHU_distances,testpoint_1_sorted_PICHU_distances )

    classified_testpoints(1,testpoint_1_sorted_PIKACHU_distances[0],testpoint_1_sorted_PICHU_distances[0])

    #Testpoint 2

    calculate_euclidean_distance(testpoints_ordered[2],testpoints_ordered[3],pikachu_x_values_width[i],pikachu_y_values_height[i])
    shortest_distance_testpoints(testpoint_2_PIKACHU_distances, testpoint_2_sorted_PIKACHU_distances)

    calculate_euclidean_distance(testpoints_ordered[2], testpoints_ordered[3],pichu_x_values_width[i],pichu_y_values_height[i])
    shortest_distance_testpoints(testpoint_2_PICHU_distances,testpoint_2_sorted_PICHU_distances )

    classified_testpoints(2,testpoint_2_sorted_PIKACHU_distances[0],testpoint_2_sorted_PICHU_distances[0])

    # testpoint 3

    calculate_euclidean_distance(testpoints_ordered[4],testpoints_ordered[5],pikachu_x_values_width[i],pikachu_y_values_height[i])
    shortest_distance_testpoints(testpoint_3_PIKACHU_distances, testpoint_3_sorted_PIKACHU_distances)

    calculate_euclidean_distance(testpoints_ordered[4], testpoints_ordered[5],pichu_x_values_width[i],pichu_y_values_height[i])
    shortest_distance_testpoints(testpoint_3_PICHU_distances,testpoint_3_sorted_PICHU_distances )

    classified_testpoints(3,testpoint_3_sorted_PIKACHU_distances[0],testpoint_3_sorted_PICHU_distances[0])

    # testpoint 4

    calculate_euclidean_distance(testpoints_ordered[6],testpoints_ordered[7],pikachu_x_values_width[i],pikachu_y_values_height[i])
    shortest_distance_testpoints(testpoint_4_PIKACHU_distances, testpoint_4_sorted_PIKACHU_distances)

    calculate_euclidean_distance(testpoints_ordered[0], testpoints_ordered[1],pichu_x_values_width[i],pichu_y_values_height[i])
    shortest_distance_testpoints(testpoint_4_PICHU_distances,testpoint_4_sorted_PICHU_distances )

    classified_testpoints(4,testpoint_4_sorted_PIKACHU_distances[0],testpoint_4_sorted_PICHU_distances[0])


    # let a user write a testpoint and classiefie it. 

    user_input_exercises("(Exercise 1) Write a testpoint (x value):")
    user_input_exercises("(Exercise 1) Write a testpoint (y value):")
    shortest_distance_testpoints(user_input[0],user_input[1])


    calculate_euclidean_distance(user_testpoint_x,user_testpoint_y,pikachu_x_values_width[i],pikachu_y_values_height[i])
    shortest_distance_testpoints(user_input_PIKACHU_distances, user_input_sorted_PIKACHU_distances)

    calculate_euclidean_distance(user_testpoint_x, user_testpoint_y,pichu_x_values_width[i],pichu_y_values_height[i])
    shortest_distance_testpoints(user_input_PICHU_distances,user_input_sorted_PICHU_distances )

    classified_user_testpoint(user_input_sorted_PIKACHU_distances, user_input_sorted_PICHU_distances)




    print("Let´s see what your testpoint is classified as when you compare it to the 10 closest datapoints:")

    user_input_PIKACHU_distances.clear()
    user_input_sorted_PIKACHU_distances.clear()
    user_input_PICHU_distances.clear()
    user_input_sorted_PICHU_distances.clear()


    user_input_exercises("(Exercise 2) Write a testpoint (x value):")
    user_input_exercises("(Exercise 2) Write a testpoint (y value):")

    calculate_euclidean_distance(user_testpoint_x, user_testpoint_y)
    shortest_distance_testpoints(user_input_PIKACHU_distances, user_input_sorted_PIKACHU_distances)
    calculate_euclidean_distance(user_testpoint_x, user_testpoint_y)
    shortest_distance_testpoints(user_input_PICHU_distances, user_input_sorted_PICHU_distances)


    ten_closest_distances()
    majority_to_classifie_testpoint()

    print("Exercise 2) The user testpoint is classified as: (based on ten majority votes.)")




#Metoder nedan


def read_data_from_file():
    # Reads datapoints cvs-file.

    with open("..\\data\\datapoints.csv") as file:
        reader = csv.DictReader(file)

        return reader


def save_datapoints_in_datastructure(reader):
    # Data inserted to a list with dictionary with 3 key-value pairs.
    
    for row in reader:
        pokemons.append({"width" : float(row["(width (cm)"].strip()), "height" : float(row[" height (cm)"].strip()), "label" : int(row[" label (0-pichu"].strip())})
    return pokemons

def divide_pikachu_and_pichu(list1, list2, zero_or_one,list3, key ):
    # The values of pichu and pikachu are seperated to two new lists. 

    list2 = [item for item in list1 if item["label"] == zero_or_one]

    for row in pichu_datapoints:
        list3.append(row["key"])

    return list3

    


def plot_matplotlib(pichu_x, pichu_y, pikachu_x, pikachu_y):

    testpoints_x_values_width = [25,24.2,22,20.5]
    testpoints_y_values_height = [32,31.5,34,34]

    plt.title("Pichu and Pikachu")
    plt.xlabel("Width (cm)")
    plt.ylabel("Height(cm)")

    plt.scatter(pichu_x, pichu_y, color = "orange", label = "Pichu") 
    plt.scatter(pikachu_x, pikachu_y, color = "green", label = "Pikachu")
    plt.scatter(testpoints_x_values_width, testpoints_y_values_height, color ="pink", label ="Testpoints")
    plt.legend()


def calculate_euclidean_distance(x1,y1,x2,y2):

    global eucladian_distance
    eucladian_distance = math.sqrt((x2-x1)**2 + (y2-y1)**2)
    return eucladian_distance

def shortest_distance_testpoints(new_list, sorted_list):
    # Adds calculated eucladian distances to a new list, then sort the list and add it to another list. 

    new_list.append(eucladian_distance)
    sorted_list = sorted(new_list)


def classified_testpoints(testpoint_number, default, pikachu_distances, pichu_distances):

    if pikachu_distances < pichu_distances: 
        print(f"Testpoint {testpoint_number} is classified as Pikachu.") 
    else:   
        print(f"Testpoint {testpoint_number} is classified as Pichu")
        

def user_input_exercises(text):

    while True:
        try: 
            user_input = (float(input(text)))
            user_input.append

            return user_input

        except ValueError:
            print("Wrong, please write an integear or float")


def classified_user_testpoint(pikachu_distances, pichu_distances):
    if pikachu_distances < pichu_distances: 
        print(f"Your testpoint is classified as Pikachu.") 
    else:   
        print(f"Your testpoint is classified as Pichu")

def user_input_excercise_2():
    ...

def shortest_distance_testpoints_exercise_2():
    ...

def ten_closest_distances():
    added_2_lists = user_input_sorted_PIKACHU_distances + user_input_sorted_PICHU_distances
    print(added_2_lists)

    sorted_list = sorted(added_2_lists)
    print(f"The list above is sorted:")
    print(sorted_list)

    ten_shortest_distances = []
    print("The 10 shortest distances are being added to a new list: ")

    count=0
    for number in sorted_list:
        if count <10:
            ten_shortest_distances.append(sorted_list[count])
            count += 1
        else: 
            break

    print(ten_shortest_distances)



    closest_to_pikachu = []
    closest_to_pichu = []

    count=0
    for number in ten_shortest_distances:
        if number in user_input_PIKACHU_distances:
            closest_to_Pikachu.append(number)
        else:
            closest_to_pichu.append(number)
        count +=1

    print("The numbers that are closest to pikachu/pichu?")

    # New row
    print()
    print("Testpoints closest to pikachu, in the closest-ten-list:")
    print(closest_to_pikachu)


    # New row
    print()


    print("Testpoints closest to pichu, in the closest-ten-list:")
    print(closest_to_pichu)


def majority_to_classifie_testpoint():
    if len(closest_to_pikachu) > len(closest_to_pichu):
        print(f"The testpoint is classified as pikachu (it´s are a majority of: {len(closest_to_pikachu)})")
    else:
        print(f"The testpoint is classified as pichu (it´s are a majority of: {len(closest_to_pichu)})")

#anropar main
main()
