# %%
import csv
import math
import matplotlib.pyplot as plt
import numpy as np 

pokemons = []

testpoints_x_values_width = []
testpoints_y_values_height = []

pichu_datapoints = []
pichu_x_values_width = []
pichu_y_values_height =[]

pikachu_datapoints = []
pikachu_x_values_width = []
pikachu_y_values_height =[]

# First I changed the file-extension of datapoints.txt to .csv instead.


# Adding datapoints from cvs-file with labels to a list with 3 dictionaries.
with open("..\\data\\datapoints.csv") as file:
    reader = csv.DictReader(file)

    # Strip() takes away the whitespace and the strings are converted to float or int.
    for row in reader:
        pokemons.append({"width" : float(row["(width (cm)"].strip()), "height" : float(row[" height (cm)"].strip()), "label" : int(row[" label (0-pichu"].strip())})




#Adding testpoints to list
#TO DO! Add testpoints through "with open". As a CSV-file or txt. Problem with converting string to float. 




# The values of pichu and pikachu seperated to two new lists. 
pichu_datapoints = [item for item in pokemons if item["label"] == 0]

pikachu_datapoints = [item for item in pokemons if item["label"] == 1]



# Made 2 new lists for x_values (width) and y_values (height) for pichu.
for row in pichu_datapoints:
    pichu_x_values_width.append(row["width"])

for row in pichu_datapoints:
    pichu_y_values_height.append(row["height"])


# Made 2 new lists for x_values (width) and y_values (height) for pikachu.
for row in pikachu_datapoints:
    pikachu_x_values_width.append(row["width"])

for row in pikachu_datapoints:
    pikachu_y_values_height.append(row["height"])


#Matplotlib layout

testpoints_x_values_width = [25,24.2,22,20.5]
testpoints_y_values_height = [32,31.5,34,34]

plt.title("Pichu and Pikachu")
plt.xlabel("Width (cm)")
plt.ylabel("Height(cm)")

plt.scatter(pikachu_x_values_width, pikachu_y_values_height, color = "green", label = "Pikachu")
plt.scatter(pichu_x_values_width, pichu_y_values_height, color = "orange", label = "Pichu") 
plt.scatter(testpoints_x_values_width, testpoints_y_values_height, color ="pink", label ="Testpoints")
plt.legend()



#Fuction to calculate the eucladian distance. 

def distance_koordinates(x1,y1,x2,y2): 
    eucladian_distance = math.sqrt((x2-x1)**2 + (y2-y1)**2)
    print(eucladian_distance)




#Testpoint 1 (25,32)

distance_koordinates(25,32,)



#Testpoint 2 (24.2,31.5)

distance_koordinates(24.2,31.5, )



#Testpoint 3 (22,34)

distance_koordinates(22,34 )



#Testpoint 4 (20.5,34)

distance_koordinates(20.5,34,)





# User input of testpoint, with try-catch. Algoritm that will determan the class.

while True:
    try:
        user_input = int(input("Please write a testpoint"))

    except ValueError:
        print("Wrong, please write an integear")

    else:
        break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Jennifer\Desktop\Skola\Github\Github\Python-Jennifer-Olausson\Labs\Labb_2.ipynb Cell 1 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/Jennifer/Desktop/Skola/Github/Github/Python-Jennifer-Olausson/Labs/Labb_2.ipynb#W0sZmlsZQ%3D%3D?line=81'>82</a>     print(eucladian_distance)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jennifer/Desktop/Skola/Github/Github/Python-Jennifer-Olausson/Labs/Labb_2.ipynb#W0sZmlsZQ%3D%3D?line=86'>87</a> #Testpoint 1 (25,32)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Jennifer/Desktop/Skola/Github/Github/Python-Jennifer-Olausson/Labs/Labb_2.ipynb#W0sZmlsZQ%3D%3D?line=88'>89</a> distance_koordinates(25,32,)
# ...
